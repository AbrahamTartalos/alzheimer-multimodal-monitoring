# %% [markdown]
# # 09e - Risk Stratification Models
#
# **Objetivo**: Desarrollar modelos de estratificación de riesgo utilizando los pipelines especializados
#
# **Componentes**:
# - Clustering para identificación de fenotipos
# - Estratificación genética y demográfica
# - Modelos probabilísticos GMM
# - Análisis jerárquico de subestratos

# %% [markdown]
# ---

# %% [markdown]
# ## Importar librerías y Configuraciones

# %%
import sys
import os
sys.path.append('../src/modeling')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

from risk_stratification import RiskStratificationPipeline

# %%
# Configuración
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
print("✅ Librerías y scripts importados correctamente")
print(f"📅 Fecha de ejecución: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Librerías y scripts importados correctamente
# 📅 Fecha de ejecución: 2025-07-18 09:35:07

# %%
# Configuración MLflow
mlflow.set_experiment("alzheimer_risk_stratification")
# Out:
# <Experiment: artifact_location='file:///E:/usuarios/alumno/Escritorio/Alzheimer-Multimodal-Monitoring/notebooks/mlruns/584507646102384124', creation_time=1752499788040, experiment_id='584507646102384124', last_update_time=1752499788040, lifecycle_stage='active', name='alzheimer_risk_stratification', tags={}>

# %% [markdown]
# ## Cargar datos procesados

# %%
# Cargar datos procesados
try:
    df = pd.read_csv('../data/processed/features/alzheimer_features_selected_20250621.csv')
    print(f"📊 Dataset cargado: {df.shape}")
    print(f"📈 Score de riesgo disponible: {df['composite_risk_score'].notna().sum()} registros")
    print(f"🎯 Distribución de categorías:")
    print(df['risk_category'].value_counts())
except FileNotFoundError:
    print("❌ Error: Archivo de features no encontrado")
    print("💡 Ejecuta primero el notebook 03_feature_engineering_master.ipynb")
# Out:
# 📊 Dataset cargado: (48466, 186)
# 📈 Score de riesgo disponible: 48466 registros
# 🎯 Distribución de categorías:
# risk_category
# Low         22501
# Moderate    22345
# High         3620
# Name: count, dtype: int64

# %% [markdown]
# ## Inicializar pipeline de estratificación y Preparar datos usando utilities

# %%
# Inicializar pipeline de estratificación
stratifier = RiskStratificationPipeline(
    target_column='composite_risk_score',
    category_column='risk_category'
)


# Preparar datos básicos (SOLO columnas numéricas)
feature_columns = df.select_dtypes(include=np.number).columns.tolist()
feature_columns = [col for col in feature_columns 
                  if col not in ['composite_risk_score', 'risk_category']]

X_processed = df[feature_columns]

# Paso CRÍTICO: Manejar valores infinitos y NaNs
X_processed = X_processed.replace([np.inf, -np.inf], np.nan)
X_processed = X_processed.fillna(0)

# Paso OPCIONAL: Si persiste el error, normalizar valores grandes
#if (X_processed.max() > 1e10).any():
#    large_cols = X_processed.columns[X_processed.max() > 1e10]
#    X_processed[large_cols] = X_processed[large_cols] / 1e9
    
print(f"🔧 Features preparadas: {len(feature_columns)}")
print(f"📊 Registros válidos: {len(X_processed)}")
# Out:
# 🔧 Features preparadas: 176
# 📊 Registros válidos: 48466

# %% [markdown]
# ## 1. Identificación de Fenotipos con K-Means

# %%
# 1. Identificación de Fenotipos con K-Means
with mlflow.start_run(run_name="phenotype_identification"):
    mlflow.set_tag("phase", "risk_stratification")
    mlflow.set_tag("method", "kmeans_clustering")
    
    # Usar el método del pipeline existente
    phenotype_results = stratifier.identify_phenotypes(
        X_processed,
        method='kmeans', 
        k_range=(2, 8)
    )
    labels = phenotype_results['labels']
    
    # Registrar resultados
    mlflow.log_params(phenotype_results['params'])
    mlflow.log_metrics(phenotype_results['metrics'])
    mlflow.sklearn.log_model(phenotype_results['model'], "phenotype_model")
    
    print(f"🧬 Fenotipos identificados: {phenotype_results['n_clusters']}")
    print(f"📊 Silhouette Score: {phenotype_results['metrics']['silhouette_score']:.3f}")
# Out:
# 2025/07/18 11:01:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/18 11:07:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🧬 Fenotipos identificados: 2
# 📊 Silhouette Score: 0.235

# %% [markdown]
# ## 2. Estratificación Genética por APOE

# %%
# 2. Estratificación Genética por APOE
if 'APOE_e4_carrier' in df.columns:
    with mlflow.start_run(run_name="genetic_stratification"):
        mlflow.set_tag("stratification_type", "genetic_apoe")
        
        # Ejecutar estratificación genética
        genetic_results = stratifier.genetic_stratification(
            df, 
            genetic_markers=['APOE_e4_carrier']
        )
        
        # Registrar métricas
        mlflow.log_metrics(genetic_results['metrics'])
        
        print("🧬 ESTRATIFICACIÓN GENÉTICA COMPLETADA")
        print(f"📊 APOE4 Carriers: {genetic_results['apoe_carrier_stats']['count']}")
        print(f"📈 Diferencia de riesgo: {genetic_results['metrics']['risk_difference']:.3f}")
# Out:
# 🧬 ESTRATIFICACIÓN GENÉTICA COMPLETADA
# 📊 APOE4 Carriers: 22905
# 📈 Diferencia de riesgo: 0.205

# %% [markdown]
# Insight clave:
#
# 1. Los portadores de APOE ε4 tienen un riesgo 20.5% mayor que los no portadores
#
# 2. Confirma el fuerte papel de este marcador genético en el riesgo de Alzheimer

# %% [markdown]
# ## 3. Estratificación Probabilística con GMM

# %%
# 3. Estratificación Probabilística con GMM
with mlflow.start_run(run_name="probabilistic_stratification"):
    mlflow.set_tag("method", "gaussian_mixture")
    
    # Ejecutar GMM
    gmm_results = stratifier.probabilistic_stratification(
        X_processed,
        method='gmm',
        n_components_range=(2, 6)
    )
    
    # Registrar modelo
    mlflow.log_params(gmm_results['params'])
    mlflow.log_metrics(gmm_results['metrics'])
    mlflow.sklearn.log_model(gmm_results['model'], "gmm_model")
    
    print(f"🎲 Componentes GMM óptimos: {gmm_results['n_components']}")
    print(f"📊 BIC Score: {gmm_results['metrics']['bic_score']:.1f}")
# Out:
# 2025/07/18 11:37:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/18 11:38:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🎲 Componentes GMM óptimos: 5
# 📊 BIC Score: -34426883.6

# %% [markdown]
# ## 4. Estratificación Jerárquica

# %%
# 4. Estratificación Jerárquica
with mlflow.start_run(run_name="hierarchical_stratification"):
    mlflow.set_tag("method", "hierarchical")
    
    # Definir criterios jerárquicos
    hierarchical_criteria = {
        'high_risk_apoe': {
            'conditions': ['risk_category == "High"', 'APOE_e4_carrier == 1'],
            'operator': 'and'
        },
        'moderate_risk_high_bio': {
            'conditions': ['risk_category == "Moderate"', 'atn_composite_score > 0.7'],
            'operator': 'and'
        }
    }
    
    # Ejecutar estratificación jerárquica
    hierarchical_results = stratifier.hierarchical_stratification(
        df,
        criteria=hierarchical_criteria
    )
    
    # Registrar resultados
    mlflow.log_metrics(hierarchical_results['metrics'])
    
    print("🏗️ ESTRATIFICACIÓN JERÁRQUICA COMPLETADA")
    print(f"📊 Subestratos identificados: {hierarchical_results['n_substrata']}")
# Out:
# 🏗️ ESTRATIFICACIÓN JERÁRQUICA COMPLETADA
# 📊 Subestratos identificados: 2

# %% [markdown]
# Subestratos identificados: 2 grupos de alto riesgo definidos:
#
# 1. Alto riesgo genético-clínico (Alto riesgo + APOE ε4+)
#
# 2. Moderado riesgo con biomarcadores elevados (Moderado + ATN > 0.7
#
#
#
# Aplicación clínica:
#
# 1. Permite identificar grupos específicos para intervenciones personalizadas
#
# 2. El grupo 1 podría beneficiarse de terapias preventivas tempranas
#
# 3. El grupo 2 podría requerir monitorización más intensiva de biomarcadores

# %% [markdown]
# ## 5. Estratificación por Biomarcadores

# %%
# 5. Estratificación por Biomarcadores
biomarker_features = [col for col in df.columns if 
                     any(marker in col.lower() for marker in ['tau', 'abeta', 'ptau'])]

if biomarker_features:
    with mlflow.start_run(run_name="biomarker_stratification"):
        mlflow.set_tag("stratification_type", "biomarker")
        
        # Ejecutar clustering de biomarcadores
        biomarker_results = stratifier.biomarker_stratification(
            df,
            biomarker_columns=biomarker_features,
            n_clusters=3
        )
        
        # Registrar modelo
        mlflow.log_params(biomarker_results['params'])
        mlflow.log_metrics(biomarker_results['metrics'])
        mlflow.sklearn.log_model(biomarker_results['model'], "biomarker_model")
        
        print("🧪 ESTRATIFICACIÓN POR BIOMARCADORES COMPLETADA")
        print(f"📊 Clusters de biomarcadores: {biomarker_results['n_clusters']}")
# Out:
# 2025/07/20 12:07:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/20 12:10:27 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\alumno\AppData\Local\Temp\tmpkvh_ofnd\model\model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.6.1', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.
# 2025/07/20 12:10:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🧪 ESTRATIFICACIÓN POR BIOMARCADORES COMPLETADA
# 📊 Clusters de biomarcadores: 3

# %% [markdown]
# ## Visualización de Resultados

# %%
# Visualización simplificada
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# 1. Distribución de fenotipos
if 'phenotypes' in stratifier.results:
    axes[0,0].hist(stratifier.results['phenotypes']['labels'], alpha=0.7)
    axes[0,0].set_title("Fenotipos Identificados")

# 2. Distribución GMM
if 'gmm' in stratifier.results:
    axes[0,1].hist(stratifier.results['gmm']['labels'], alpha=0.7)
    axes[0,1].set_title("Componentes GMM")

# 3. Distribución de riesgo (agregar ax)
stratifier.plot_risk_distribution_by_strata(ax=axes[1,0])

# 4. Métricas de calidad
quality_metrics = stratifier.compute_stratification_quality()
if quality_metrics:
    metrics_names = list(quality_metrics.keys())
    metrics_values = list(quality_metrics.values())
    axes[1,1].bar(metrics_names, metrics_values)
    axes[1,1].set_title("Métricas de Calidad")
    axes[1,1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Resumen Final, Exportación y Guardado resultados

# %%
# Resumen Final y Exportación
print("\n" + "="*60)
print("📊 RESUMEN DE ESTRATIFICACIÓN DE RIESGO")
print("="*60)

# Compilar resumen
summary_stats = stratifier.generate_summary_report()

for category, stats in summary_stats.items():
    print(f"\n🎯 {category.upper()}:")
    for key, value in stats.items():
        print(f"   • {key}: {value}")
# Out:
# ============================================================
# 📊 RESUMEN DE ESTRATIFICACIÓN DE RIESGO
# ============================================================
#
# 🎯 PHENOTYPES:
#    • n_clusters: 2
#    • silhouette_score: 0.235
#
# 🎯 GENETIC:
#    • risk_difference: 0.205
#    • carriers_analyzed: 22905
#
# 🎯 GMM:
#    • n_components: 5
#    • bic_score: -34426883.6

# %%
# Guardar resultados consolidados
consolidated_results = stratifier.consolidate_results()
consolidated_results.to_csv('../data/processed/risk_stratification_results.csv', index=False)

# Guardar modelos para la siguiente fase
model_artifacts = stratifier.models

# Exportar para fase de evaluación
#import joblib
#joblib.dump(model_artifacts, '../models/stratification_models.joblib')

print("\n✅ Estratificación de riesgo completada exitosamente")
print("📁 Modelos guardados en MLflow y ../models/")
print("📊 Resultados exportados a ../data/processed/")
print("🔄 Listo para Fase 5: Evaluación y Optimización")
# Out:
# ✅ Estratificación de riesgo completada exitosamente
# 📁 Modelos guardados en MLflow y ../models/
# 📊 Resultados exportados a ../data/processed/
# 🔄 Listo para Fase 5: Evaluación y Optimización

# %% [markdown]
# ## Hallazgos Clave

# %% [markdown]
# Hallazgos clave:
#
# 1. La población se divide naturalmente en 2-5 subgrupos según el método
#
# 2. APOE ε4 es el factor individual más determinante de riesgo
#
# 3. Existe un grupo de "riesgo moderado con biomarcadores elevados" que requiere atención especial
#
# 4. Los modelos tienen calidad suficiente para pasar a la fase de evaluación clínica

# %% [markdown]
# ---

# %% [markdown]
# __Abraham Tartalos__
